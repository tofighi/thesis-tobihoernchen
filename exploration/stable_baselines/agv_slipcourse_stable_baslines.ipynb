# %%
import sys
import time
sys.path.append("../..")
from thesis.envs.agv_slipcourse import AgvSlipCourse
from stable_baselines3 import PPO
from stable_baselines3.common.utils import set_random_seed

# %%
seed = 42
set_random_seed(seed)

# %%
models_dir = "../../models/AgvSlipCourse/PPO"
logdir = "../../logs/AgvSlipCourse"
run_name = f"PPO-{time.time()}-{seed}"

# %%
env = AgvSlipCourse("../../envs\AGV_SlipCourse Exported\AGV_SlipCourse.zip", 100)
# Out:
# c:\Users\Wegma\.conda\envs\thesis\lib\site-packages\alpyne\client\utils.py:124: UserWarning: Unzipping to temporary directory (C:\Users\Wegma\AppData\Local\Temp\alpyne_58286_k9z1z7zp)
#   warn(f"Unzipping to temporary directory ({tmp_dir})")

# %%
model = PPO(
    "MlpPolicy", 
    env, 
    tensorboard_log= logdir
    )

# %%
TIMESTEPS = 10000
for i in range(1, 30):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=run_name)
    model.save(f"{models_dir}/{run_name}-{TIMESTEPS * i}")
